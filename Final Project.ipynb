# %%
# API QUOTA OF 10K UNITS PER DAY
# UNIT IS A LIST OF VIDEOS CONTAINING 1-50 VIDEOS

# %%
# !pip install --upgrade google-api-python-client
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2
import pandas as pd
import numpy as np
import googleapiclient.discovery

# %%
# API information
api_service_name = "youtube"
api_version = "v3"
API_KEY_Yonatan = 'AIzaSyAFtqiMuw9RC-Ue7tVH4MMaVljW6UwYFt0'
API_KEY_Naor = 'AIzaSyB9f024LUQ1-I3XxTjAZexOws3z1P650PY'
# API client
youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = API_KEY_Naor)

# %%
# Spotify-2000.csv - https://www.kaggle.com/datasets/iamsumat/spotify-top-2000s-mega-dataset
# top10s.csv - https://www.kaggle.com/datasets/leonardopena/top-spotify-songs-from-20102019-by-year
# spotify1921-2020.csv - https://www.kaggle.com/datasets/ektanegi/spotifydata-19212020
data1 = pd.read_csv('Spotify-2000.csv')
data2 = pd.read_csv('top10s.csv',encoding='latin1')
data3 = pd.read_csv('spotify1921-2020.csv')

# %%
data3
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308  0.7610         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787  0.4280         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.563000   10    0.1510   -12.428     1
# 1               0.901000    8    0.0763   -28.454     1
# 2               0.000000    5    0.1190   -19.924     0
# 3               0.887000    1    0.1110   -14.734     0
# 4               0.908000   11    0.0980   -16.829     1
# ...                  ...  ...       ...       ...   ...
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 19 columns]

# %%
data3['release_date_dummy'] = data3['release_date'].apply(lambda x: x.split('-')[0]).astype(int)

# %%
wanted_songs = data3[data3["release_date_dummy"]>2007]

# %%
wanted_songs['artists_dummy'] = wanted_songs['artists'].apply(lambda x: x[1:-1].split(',')).apply(lambda lis: " ".join([art.strip('"\' ') for art in lis]))
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_9588/451472928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wanted_songs['artists_dummy'] = wanted_songs['artists'].apply(lambda x: x[1:-1].split(',')).apply(lambda lis: " ".join([art.strip('"\' ') for art in lis]))

# %%
wanted_songs[['name','artists_dummy','release_date_dummy']]
# Out:
#                                   name                artists_dummy  \
# 6854                       Hard 2 Love                      Haystak
# 6855                                27                 Fall Out Boy
# 6856                            Devour                    Shinedown
# 6857               Chill Or Be Chilled                     Oli Silk
# 6858                   I Know You Know           Esperanza Spalding
# ...                                ...                          ...
# 169904   Skechers (feat. Tyga) - Remix              DripReport Tyga
# 169905  Sweeter (feat. Terrace Martin)  Leon Bridges Terrace Martin
# 169906                How Would I Know               Kygo Oh Wonder
# 169907                     I Found You       Cash Cash Andy Grammer
# 169908           More Hearts Than Mine               Ingrid Andress
#
#         release_date_dummy
# 6854                  2008
# 6855                  2008
# 6856                  2008
# 6857                  2008
# 6858                  2008
# ...                    ...
# 169904                2020
# 169905                2020
# 169906                2020
# 169907                2020
# 169908                2020
#
# [25656 rows x 3 columns]

# %%
queries = wanted_songs[['name','artists_dummy']].apply(" ".join, axis=1)

# %%
query_list = queries.values.tolist()

# %%
sample = query_list[:50]
sample
# Out:
# ['Hard 2 Love Haystak',
#  '27 Fall Out Boy',
#  'Devour Shinedown',
#  'Chill Or Be Chilled Oli Silk',
#  'I Know You Know Esperanza Spalding',
#  'Hot N Cold Katy Perry',
#  'Sin Perdón Héctor Acosta "El Torito',
#  "I'm Just Talkin' About Tonight Toby Keith",
#  'Cry For You - Radio Mix September',
#  'What a Shame Shinedown',
#  'Strange Overtones David Byrne',
#  'A Dark Knight Hans Zimmer James Newton Howard',
#  'No Me Diga Andrea Burns Janet Dacal Karen Olivo Mandy Gonzalez',
#  'Ultraviolet Stiff Dylans',
#  'Bésame Mucho Los Panchos',
#  'Ride Through the Country (feat. John Michael Montgomery) Colt Ford John Michael Montgomery',
#  'Bruises & Bitemarks Good With Grenades',
#  'Porcelain Moby',
#  'Courtesy Of The Red, White And Blue (The Angry American) Toby Keith',
#  'Rocky Top The Osborne Brothers',
#  "Thuggin' (feat. Lil' Phat & Shell of 3 Deep and Lil' Boosie) Webbie Boosie Badazz Lil' Phat & Shell of 3 Deep",
#  'Cumbersome Seven Mary Three',
#  "(Don't Fear) The Reaper - Single Version Blue Öyster Cult",
#  'Ravel: String Quartet, M. 35: II. Assez vif - Très rythmé Maurice Ravel Quatuor Ébène',
#  'You Make Me Sick Egypt Central',
#  'Lazy Days Shwayze Cisco Adler',
#  'Just Like Me Jamie Foxx T.I.',
#  'Vultures - Live at the Nokia Theatre, Los Angeles, CA - December 2007 John Mayer',
#  "Soon We'll Be Found Sia",
#  'One Woman Randy Rogers Band',
#  'Unanswered Suicide Silence',
#  'Cold Shoulder Adele',
#  'Space Age Love Song A Flock Of Seagulls',
#  'The Diary Hollywood Undead',
#  'Do What You Do Mudvayne',
#  'When It Rains Eli Young Band',
#  'Next Go Round Nickelback',
#  'I Kissed A Girl Katy Perry',
#  '最長的電影 Jay Chou',
#  'Cyanide Metallica',
#  '9MM David Banner Akon Snoop Dogg Lil Wayne',
#  'Be With You Akon',
#  'Tengo Ganas Víctor Manuelle',
#  'Two Cups of Tea Star Fucking Hipsters',
#  'Si Me Vas A Dejar Lalo Mora',
#  'Audience Of One Rise Against',
#  'Make the Road By Walking Menahan Street Band',
#  'Light It Up Rev Theory',
#  'Let It Rock Kevin Rudolf Lil Wayne',
#  'Aparentemente Tony Vega']

# %%
# This costs 100 per execution. 
def search_song(song_query=''):
    song_video_id = youtube.search().list(
            part="id",
            type='video',
            regionCode="US",
            order="relevance",
            q=song_query,
            maxResults=1,
            fields="items(id(videoId))"
    ).execute()
    return song_video_id

# %%
from tqdm import tqdm
song_ids = dict()
for song_name in tqdm(sample):
    res = search_song(song_name)
#         song_ids[song_name] = res['items'][0]['id']['videoId']
    song_ids[song_name] = res
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:24<00:00,  2.05it/s]

# %%
song_ids
# Out:
# {'Hard 2 Love Haystak': {'items': [{'id': {'videoId': 'EU-9mJmsvCo'}}]},
#  '27 Fall Out Boy': {'items': [{'id': {'videoId': '0YdaXlp3thM'}}]},
#  'Devour Shinedown': {'items': [{'id': {'videoId': '0QXNtLaOnSE'}}]},
#  'Chill Or Be Chilled Oli Silk': {'items': [{'id': {'videoId': '7yiEZ9i3v-g'}}]},
#  'I Know You Know Esperanza Spalding': {'items': [{'id': {'videoId': '0NfQmoouvTY'}}]},
#  'Hot N Cold Katy Perry': {'items': [{'id': {'videoId': 'kTHNpusq654'}}]},
#  'Sin Perdón Héctor Acosta "El Torito': {'items': [{'id': {'videoId': 'ot6wDVHqVNw'}}]},
#  "I'm Just Talkin' About Tonight Toby Keith": {'items': [{'id': {'videoId': 'wMKTB95-LVk'}}]},
#  'Cry For You - Radio Mix September': {'items': [{'id': {'videoId': 'si0VFSOH0wQ'}}]},
#  'What a Shame Shinedown': {'items': [{'id': {'videoId': 'YMtPc19EP90'}}]},
#  'Strange Overtones David Byrne': {'items': [{'id': {'videoId': '-L7IdUqaZxo'}}]},
#  'A Dark Knight Hans Zimmer James Newton Howard': {'items': [{'id': {'videoId': 'Gn2Qfz3sWXY'}}]},
#  'No Me Diga Andrea Burns Janet Dacal Karen Olivo Mandy Gonzalez': {'items': [{'id': {'videoId': 'gm43fzmGZOs'}}]},
#  'Ultraviolet Stiff Dylans': {'items': [{'id': {'videoId': 'kCOvld3nh7I'}}]},
#  'Bésame Mucho Los Panchos': {'items': [{'id': {'videoId': 'pwRiKDcrjz0'}}]},
#  'Ride Through the Country (feat. John Michael Montgomery) Colt Ford John Michael Montgomery': {'items': [{'id': {'videoId': 'Pee07DX6tXw'}}]},
#  'Bruises & Bitemarks Good With Grenades': {'items': [{'id': {'videoId': 'bjyhJGe_uRw'}}]},
#  'Porcelain Moby': {'items': [{'id': {'videoId': 'IJWlBfo5Oj0'}}]},
#  'Courtesy Of The Red, White And Blue (The Angry American) Toby Keith': {'items': [{'id': {'videoId': 'ruNrdmjcNTc'}}]},
#  'Rocky Top The Osborne Brothers': {'items': [{'id': {'videoId': '_n9prNixjbg'}}]},
#  "Thuggin' (feat. Lil' Phat & Shell of 3 Deep and Lil' Boosie) Webbie Boosie Badazz Lil' Phat & Shell of 3 Deep": {'items': [{'id': {'videoId': 'FBvghSnukqQ'}}]},
#  'Cumbersome Seven Mary Three': {'items': [{'id': {'videoId': 'NjNn4bbbgSw'}}]},
#  "(Don't Fear) The Reaper - Single Version Blue Öyster Cult": {'items': [{'id': {'videoId': 'QHUuG2Dcxnk'}}]},
#  'Ravel: String Quartet, M. 35: II. Assez vif - Très rythmé Maurice Ravel Quatuor Ébène': {'items': [{'id': {'videoId': '0VVYFlbLDOI'}}]},
#  'You Make Me Sick Egypt Central': {'items': [{'id': {'videoId': 'eycOSzDJP2U'}}]},
#  'Lazy Days Shwayze Cisco Adler': {'items': [{'id': {'videoId': 'V6DL8nXUoRU'}}]},
#  'Just Like Me Jamie Foxx T.I.': {'items': [{'id': {'videoId': '9rH-68PdAWc'}}]},
#  'Vultures - Live at the Nokia Theatre, Los Angeles, CA - December 2007 John Mayer': {'items': [{'id': {'videoId': 'qUGzdbGBEFI'}}]},
#  "Soon We'll Be Found Sia": {'items': [{'id': {'videoId': 't1x8DMfbYN4'}}]},
#  'One Woman Randy Rogers Band': {'items': [{'id': {'videoId': '_x0qsm2Uc3o'}}]},
#  'Unanswered Suicide Silence': {'items': [{'id': {'videoId': '_Yr5rn3Sv_4'}}]},
#  'Cold Shoulder Adele': {'items': [{'id': {'videoId': 'uGwH-x4VoH8'}}]},
#  'Space Age Love Song A Flock Of Seagulls': {'items': [{'id': {'videoId': 'gOK3rqVgN2I'}}]},
#  'The Diary Hollywood Undead': {'items': [{'id': {'videoId': 'j7bPePvGnJw'}}]},
#  'Do What You Do Mudvayne': {'items': [{'id': {'videoId': 'x8y_Y-7P6gg'}}]},
#  'When It Rains Eli Young Band': {'items': [{'id': {'videoId': 'qMF4B3wDO_E'}}]},
#  'Next Go Round Nickelback': {'items': [{'id': {'videoId': 'FQfjiPthhoU'}}]},
#  'I Kissed A Girl Katy Perry': {'items': [{'id': {'videoId': 'tAp9BKosZXs'}}]},
#  '最長的電影 Jay Chou': {'items': [{'id': {'videoId': '2zxc27bvrO8'}}]},
#  'Cyanide Metallica': {'items': [{'id': {'videoId': 'bnJzsdNwFu0'}}]},
#  '9MM David Banner Akon Snoop Dogg Lil Wayne': {'items': [{'id': {'videoId': 'GtPjQr77OTA'}}]},
#  'Be With You Akon': {'items': [{'id': {'videoId': 'QOU-PmvP840'}}]},
#  'Tengo Ganas Víctor Manuelle': {'items': [{'id': {'videoId': 'LvJcDhDYiXM'}}]},
#  'Two Cups of Tea Star Fucking Hipsters': {'items': [{'id': {'videoId': 'h-KoReUJyeY'}}]},
#  'Si Me Vas A Dejar Lalo Mora': {'items': [{'id': {'videoId': 'LC_I9FsygFg'}}]},
#  'Audience Of One Rise Against': {'items': [{'id': {'videoId': '4MjLKjPc7q8'}}]},
#  'Make the Road By Walking Menahan Street Band': {'items': [{'id': {'videoId': 'bQPfmVzkzgg'}}]},
#  'Light It Up Rev Theory': {'items': [{'id': {'videoId': '_3bQ49ZUgG8'}}]},
#  'Let It Rock Kevin Rudolf Lil Wayne': {'items': [{'id': {'videoId': 'u0n4eMGXAyk'}}]},
#  'Aparentemente Tony Vega': {'items': [{'id': {'videoId': '_2h3k1lmAvA'}}]}}

# %%
song_ids_cleaned = dict()
for song, id_tuple in song_ids.items():
    song_ids_cleaned[song] = id_tuple['items'][0]['id']['videoId']

# %%
song_ids_cleaned
# Out:
# {'Hard 2 Love Haystak': 'EU-9mJmsvCo',
#  '27 Fall Out Boy': '0YdaXlp3thM',
#  'Devour Shinedown': '0QXNtLaOnSE',
#  'Chill Or Be Chilled Oli Silk': '7yiEZ9i3v-g',
#  'I Know You Know Esperanza Spalding': '0NfQmoouvTY',
#  'Hot N Cold Katy Perry': 'kTHNpusq654',
#  'Sin Perdón Héctor Acosta "El Torito': 'ot6wDVHqVNw',
#  "I'm Just Talkin' About Tonight Toby Keith": 'wMKTB95-LVk',
#  'Cry For You - Radio Mix September': 'si0VFSOH0wQ',
#  'What a Shame Shinedown': 'YMtPc19EP90',
#  'Strange Overtones David Byrne': '-L7IdUqaZxo',
#  'A Dark Knight Hans Zimmer James Newton Howard': 'Gn2Qfz3sWXY',
#  'No Me Diga Andrea Burns Janet Dacal Karen Olivo Mandy Gonzalez': 'gm43fzmGZOs',
#  'Ultraviolet Stiff Dylans': 'kCOvld3nh7I',
#  'Bésame Mucho Los Panchos': 'pwRiKDcrjz0',
#  'Ride Through the Country (feat. John Michael Montgomery) Colt Ford John Michael Montgomery': 'Pee07DX6tXw',
#  'Bruises & Bitemarks Good With Grenades': 'bjyhJGe_uRw',
#  'Porcelain Moby': 'IJWlBfo5Oj0',
#  'Courtesy Of The Red, White And Blue (The Angry American) Toby Keith': 'ruNrdmjcNTc',
#  'Rocky Top The Osborne Brothers': '_n9prNixjbg',
#  "Thuggin' (feat. Lil' Phat & Shell of 3 Deep and Lil' Boosie) Webbie Boosie Badazz Lil' Phat & Shell of 3 Deep": 'FBvghSnukqQ',
#  'Cumbersome Seven Mary Three': 'NjNn4bbbgSw',
#  "(Don't Fear) The Reaper - Single Version Blue Öyster Cult": 'QHUuG2Dcxnk',
#  'Ravel: String Quartet, M. 35: II. Assez vif - Très rythmé Maurice Ravel Quatuor Ébène': '0VVYFlbLDOI',
#  'You Make Me Sick Egypt Central': 'eycOSzDJP2U',
#  'Lazy Days Shwayze Cisco Adler': 'V6DL8nXUoRU',
#  'Just Like Me Jamie Foxx T.I.': '9rH-68PdAWc',
#  'Vultures - Live at the Nokia Theatre, Los Angeles, CA - December 2007 John Mayer': 'qUGzdbGBEFI',
#  "Soon We'll Be Found Sia": 't1x8DMfbYN4',
#  'One Woman Randy Rogers Band': '_x0qsm2Uc3o',
#  'Unanswered Suicide Silence': '_Yr5rn3Sv_4',
#  'Cold Shoulder Adele': 'uGwH-x4VoH8',
#  'Space Age Love Song A Flock Of Seagulls': 'gOK3rqVgN2I',
#  'The Diary Hollywood Undead': 'j7bPePvGnJw',
#  'Do What You Do Mudvayne': 'x8y_Y-7P6gg',
#  'When It Rains Eli Young Band': 'qMF4B3wDO_E',
#  'Next Go Round Nickelback': 'FQfjiPthhoU',
#  'I Kissed A Girl Katy Perry': 'tAp9BKosZXs',
#  '最長的電影 Jay Chou': '2zxc27bvrO8',
#  'Cyanide Metallica': 'bnJzsdNwFu0',
#  '9MM David Banner Akon Snoop Dogg Lil Wayne': 'GtPjQr77OTA',
#  'Be With You Akon': 'QOU-PmvP840',
#  'Tengo Ganas Víctor Manuelle': 'LvJcDhDYiXM',
#  'Two Cups of Tea Star Fucking Hipsters': 'h-KoReUJyeY',
#  'Si Me Vas A Dejar Lalo Mora': 'LC_I9FsygFg',
#  'Audience Of One Rise Against': '4MjLKjPc7q8',
#  'Make the Road By Walking Menahan Street Band': 'bQPfmVzkzgg',
#  'Light It Up Rev Theory': '_3bQ49ZUgG8',
#  'Let It Rock Kevin Rudolf Lil Wayne': 'u0n4eMGXAyk',
#  'Aparentemente Tony Vega': '_2h3k1lmAvA'}

# %%
import json
with open('SongsIds_1_50.json', 'w') as fp:
    json.dump(song_ids_cleaned, fp)

# %%
songs_data=dict()

for song_name,vidId in song_ids_cleaned.items():
    r = youtube.videos().list(
        part="statistics,contentDetails",
        id=vidId,
        fields="items(statistics,contentDetails)"
    ).execute()
    
    songs_data[song_name] = r

# %%
songs_data
# Out:
# {'Hard 2 Love Haystak': {'items': [{'contentDetails': {'duration': 'PT4M31S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '19896301',
#      'likeCount': '193625',
#      'favoriteCount': '0',
#      'commentCount': '2153'}}]},
#  '27 Fall Out Boy': {'items': [{'contentDetails': {'duration': 'PT3M13S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['CA', 'MX', 'US']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '492662',
#      'likeCount': '6477',
#      'favoriteCount': '0',
#      'commentCount': '90'}}]},
#  'Devour Shinedown': {'items': [{'contentDetails': {'duration': 'PT3M49S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '12883626',
#      'likeCount': '75710',
#      'favoriteCount': '0',
#      'commentCount': '3888'}}]},
#  'Chill Or Be Chilled Oli Silk': {'items': [{'contentDetails': {'duration': 'PT3M44S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['CA', 'US']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '31936',
#      'likeCount': '472',
#      'favoriteCount': '0',
#      'commentCount': '5'}}]},
#  'I Know You Know Esperanza Spalding': {'items': [{'contentDetails': {'duration': 'PT3M46S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '590869',
#      'likeCount': '12874',
#      'favoriteCount': '0',
#      'commentCount': '55'}}]},
#  'Hot N Cold Katy Perry': {'items': [{'contentDetails': {'duration': 'PT4M44S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'blocked': ['AF',
#        'AX',
#        'BL',
#        'BM',
#        'BQ',
#        'CW',
#        'GG',
#        'GL',
#        'IM',
#        'JE',
#        'KG',
#        'ME',
#        'MF',
#        'MK',
#        'MM',
#        'PS',
#        'RS',
#        'SS',
#        'SX',
#        'VA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '1115632088',
#      'likeCount': '5227090',
#      'favoriteCount': '0',
#      'commentCount': '193696'}}]},
#  'Sin Perdón Héctor Acosta "El Torito': {'items': [{'contentDetails': {'duration': 'PT4M14S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '7642821',
#      'likeCount': '29223',
#      'favoriteCount': '0',
#      'commentCount': '237'}}]},
#  "I'm Just Talkin' About Tonight Toby Keith": {'items': [{'contentDetails': {'duration': 'PT3M26S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '4451285',
#      'likeCount': '17697',
#      'favoriteCount': '0',
#      'commentCount': '484'}}]},
#  'Cry For You - Radio Mix September': {'items': [{'contentDetails': {'duration': 'PT2M53S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '9674899',
#      'likeCount': '115961',
#      'favoriteCount': '0',
#      'commentCount': '2040'}}]},
#  'What a Shame Shinedown': {'items': [{'contentDetails': {'duration': 'PT4M19S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AW',
#        'BA',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LV',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '4554191',
#      'likeCount': '47037',
#      'favoriteCount': '0',
#      'commentCount': '185'}}]},
#  'Strange Overtones David Byrne': {'items': [{'contentDetails': {'duration': 'PT4M18S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '658523',
#      'likeCount': '6575',
#      'favoriteCount': '0',
#      'commentCount': '231'}}]},
#  'A Dark Knight Hans Zimmer James Newton Howard': {'items': [{'contentDetails': {'duration': 'PT16M16S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '28393',
#      'likeCount': '604',
#      'favoriteCount': '0',
#      'commentCount': '28'}}]},
#  'No Me Diga Andrea Burns Janet Dacal Karen Olivo Mandy Gonzalez': {'items': [{'contentDetails': {'duration': 'PT2M25S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '19187',
#      'likeCount': '413',
#      'favoriteCount': '0',
#      'commentCount': '3'}}]},
#  'Ultraviolet Stiff Dylans': {'items': [{'contentDetails': {'duration': 'PT3M49S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '678197',
#      'likeCount': '9071',
#      'favoriteCount': '0',
#      'commentCount': '205'}}]},
#  'Bésame Mucho Los Panchos': {'items': [{'contentDetails': {'duration': 'PT3M5S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '6653106',
#      'likeCount': '27361',
#      'favoriteCount': '0',
#      'commentCount': '701'}}]},
#  'Ride Through the Country (feat. John Michael Montgomery) Colt Ford John Michael Montgomery': {'items': [{'contentDetails': {'duration': 'PT4M35S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '1241916',
#      'likeCount': '10890',
#      'favoriteCount': '0',
#      'commentCount': '134'}}]},
#  'Bruises & Bitemarks Good With Grenades': {'items': [{'contentDetails': {'duration': 'PT3M3S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '1233691',
#      'likeCount': '10557',
#      'favoriteCount': '0',
#      'commentCount': '1448'}}]},
#  'Porcelain Moby': {'items': [{'contentDetails': {'duration': 'PT3M12S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '18262175',
#      'likeCount': '140519',
#      'favoriteCount': '0',
#      'commentCount': '4065'}}]},
#  'Courtesy Of The Red, White And Blue (The Angry American) Toby Keith': {'items': [{'contentDetails': {'duration': 'PT3M20S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'true',
#      'licensedContent': True,
#      'regionRestriction': {'blocked': ['IO', 'KP', 'SS']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '58632538',
#      'likeCount': '365040',
#      'favoriteCount': '0',
#      'commentCount': '44637'}}]},
#  'Rocky Top The Osborne Brothers': {'items': [{'contentDetails': {'duration': 'PT2M58S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '15743416',
#      'likeCount': '68659',
#      'favoriteCount': '0',
#      'commentCount': '4044'}}]},
#  "Thuggin' (feat. Lil' Phat & Shell of 3 Deep and Lil' Boosie) Webbie Boosie Badazz Lil' Phat & Shell of 3 Deep": {'items': [{'contentDetails': {'duration': 'PT4M17S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['US']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '247702',
#      'likeCount': '2398',
#      'favoriteCount': '0',
#      'commentCount': '3'}}]},
#  'Cumbersome Seven Mary Three': {'items': [{'contentDetails': {'duration': 'PT4M',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '45691659',
#      'likeCount': '269422',
#      'favoriteCount': '0',
#      'commentCount': '8790'}}]},
#  "(Don't Fear) The Reaper - Single Version Blue Öyster Cult": {'items': [{'contentDetails': {'duration': 'PT3M52S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '74335',
#      'likeCount': '694',
#      'favoriteCount': '0',
#      'commentCount': '72'}}]},
#  'Ravel: String Quartet, M. 35: II. Assez vif - Très rythmé Maurice Ravel Quatuor Ébène': {'items': [{'contentDetails': {'duration': 'PT6M30S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '70131',
#      'likeCount': '1145',
#      'favoriteCount': '0',
#      'commentCount': '16'}}]},
#  'You Make Me Sick Egypt Central': {'items': [{'contentDetails': {'duration': 'PT3M51S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '408994',
#      'likeCount': '4583',
#      'favoriteCount': '0',
#      'commentCount': '167'}}]},
#  'Lazy Days Shwayze Cisco Adler': {'items': [{'contentDetails': {'duration': 'PT3M38S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AT',
#        'AU',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SI',
#        'SK',
#        'SV',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'VE',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '114088',
#      'likeCount': '1502',
#      'favoriteCount': '0',
#      'commentCount': '4'}}]},
#  'Just Like Me Jamie Foxx T.I.': {'items': [{'contentDetails': {'duration': 'PT3M49S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '39414626',
#      'likeCount': '216146',
#      'favoriteCount': '0',
#      'commentCount': '5208'}}]},
#  'Vultures - Live at the Nokia Theatre, Los Angeles, CA - December 2007 John Mayer': {'items': [{'contentDetails': {'duration': 'PT5M20S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '464808',
#      'likeCount': '4127',
#      'favoriteCount': '0',
#      'commentCount': '13'}}]},
#  "Soon We'll Be Found Sia": {'items': [{'contentDetails': {'duration': 'PT4M1S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '91306564',
#      'likeCount': '458816',
#      'favoriteCount': '0',
#      'commentCount': '15256'}}]},
#  'One Woman Randy Rogers Band': {'items': [{'contentDetails': {'duration': 'PT4M6S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '288490',
#      'likeCount': '3449',
#      'favoriteCount': '0',
#      'commentCount': '8'}}]},
#  'Unanswered Suicide Silence': {'items': [{'contentDetails': {'duration': 'PT2M22S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '32011506',
#      'likeCount': '180885',
#      'favoriteCount': '0',
#      'commentCount': '24444'}}]},
#  'Cold Shoulder Adele': {'items': [{'contentDetails': {'duration': 'PT3M12S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '34747808',
#      'likeCount': '65423',
#      'favoriteCount': '0',
#      'commentCount': '4266'}}]},
#  'Space Age Love Song A Flock Of Seagulls': {'items': [{'contentDetails': {'duration': 'PT3M25S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '6948663',
#      'likeCount': '70740',
#      'favoriteCount': '0',
#      'commentCount': '5585'}}]},
#  'The Diary Hollywood Undead': {'items': [{'contentDetails': {'duration': 'PT4M36S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {'ytRating': 'ytAgeRestricted'},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '3140438',
#      'likeCount': '27702',
#      'favoriteCount': '0',
#      'commentCount': '1773'}}]},
#  'Do What You Do Mudvayne': {'items': [{'contentDetails': {'duration': 'PT3M38S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '7122976',
#      'likeCount': '46156',
#      'favoriteCount': '0',
#      'commentCount': '1723'}}]},
#  'When It Rains Eli Young Band': {'items': [{'contentDetails': {'duration': 'PT3M34S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '3606163',
#      'likeCount': '15781',
#      'favoriteCount': '0',
#      'commentCount': '450'}}]},
#  'Next Go Round Nickelback': {'items': [{'contentDetails': {'duration': 'PT3M44S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '2201448',
#      'likeCount': '19260',
#      'favoriteCount': '0',
#      'commentCount': '59'}}]},
#  'I Kissed A Girl Katy Perry': {'items': [{'contentDetails': {'duration': 'PT3M5S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'blocked': ['AF',
#        'AX',
#        'BL',
#        'BM',
#        'BQ',
#        'CW',
#        'GG',
#        'GL',
#        'IM',
#        'JE',
#        'KG',
#        'ME',
#        'MF',
#        'MK',
#        'MM',
#        'PM',
#        'PS',
#        'RS',
#        'SS',
#        'SX',
#        'UM',
#        'VA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '254465186',
#      'likeCount': '2473773',
#      'favoriteCount': '0',
#      'commentCount': '143321'}}]},
#  '最長的電影 Jay Chou': {'items': [{'contentDetails': {'duration': 'PT3M58S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '27619062',
#      'likeCount': '62010',
#      'favoriteCount': '0',
#      'commentCount': '2743'}}]},
#  'Cyanide Metallica': {'items': [{'contentDetails': {'duration': 'PT6M40S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '2511381',
#      'likeCount': '29583',
#      'favoriteCount': '0',
#      'commentCount': '427'}}]},
#  '9MM David Banner Akon Snoop Dogg Lil Wayne': {'items': [{'contentDetails': {'duration': 'PT4M12S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '3438271',
#      'likeCount': '36089',
#      'favoriteCount': '0',
#      'commentCount': '1297'}}]},
#  'Be With You Akon': {'items': [{'contentDetails': {'duration': 'PT3M50S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '10262082',
#      'likeCount': '70831',
#      'favoriteCount': '0',
#      'commentCount': '2040'}}]},
#  'Tengo Ganas Víctor Manuelle': {'items': [{'contentDetails': {'duration': 'PT4M26S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '170578447',
#      'likeCount': '407546',
#      'favoriteCount': '0',
#      'commentCount': '5477'}}]},
#  'Two Cups of Tea Star Fucking Hipsters': {'items': [{'contentDetails': {'duration': 'PT3M39S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '79318',
#      'likeCount': '1412',
#      'favoriteCount': '0',
#      'commentCount': '54'}}]},
#  'Si Me Vas A Dejar Lalo Mora': {'items': [{'contentDetails': {'duration': 'PT2M32S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '6321585',
#      'likeCount': '25787',
#      'favoriteCount': '0',
#      'commentCount': '491'}}]},
#  'Audience Of One Rise Against': {'items': [{'contentDetails': {'duration': 'PT4M9S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '15852343',
#      'likeCount': '53799',
#      'favoriteCount': '0',
#      'commentCount': '5310'}}]},
#  'Make the Road By Walking Menahan Street Band': {'items': [{'contentDetails': {'duration': 'PT4M8S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': False,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '435237',
#      'likeCount': '4645',
#      'favoriteCount': '0',
#      'commentCount': '235'}}]},
#  'Light It Up Rev Theory': {'items': [{'contentDetails': {'duration': 'PT4M12S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '6869001',
#      'likeCount': '41148',
#      'favoriteCount': '0',
#      'commentCount': '1851'}}]},
#  'Let It Rock Kevin Rudolf Lil Wayne': {'items': [{'contentDetails': {'duration': 'PT3M54S',
#      'dimension': '2d',
#      'definition': 'sd',
#      'caption': 'false',
#      'licensedContent': True,
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '52667704',
#      'likeCount': '326163',
#      'favoriteCount': '0',
#      'commentCount': '23133'}}]},
#  'Aparentemente Tony Vega': {'items': [{'contentDetails': {'duration': 'PT5M5S',
#      'dimension': '2d',
#      'definition': 'hd',
#      'caption': 'false',
#      'licensedContent': True,
#      'regionRestriction': {'allowed': ['AE',
#        'AR',
#        'AS',
#        'AT',
#        'AU',
#        'AW',
#        'BA',
#        'BE',
#        'BG',
#        'BH',
#        'BM',
#        'BO',
#        'BR',
#        'BY',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GF',
#        'GP',
#        'GR',
#        'GT',
#        'GU',
#        'HK',
#        'HN',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JP',
#        'KR',
#        'KW',
#        'KY',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MK',
#        'MP',
#        'MT',
#        'MX',
#        'MY',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PF',
#        'PG',
#        'PH',
#        'PL',
#        'PR',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'SA',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SV',
#        'TC',
#        'TH',
#        'TR',
#        'TW',
#        'UA',
#        'US',
#        'UY',
#        'VE',
#        'VI',
#        'ZA']},
#      'contentRating': {},
#      'projection': 'rectangular'},
#     'statistics': {'viewCount': '50426',
#      'likeCount': '506',
#      'favoriteCount': '0',
#      'commentCount': '0'}}]}}

# %%
with open('SongsData_1_50.json', 'w') as fp:
    json.dump(songs_data, fp)

# %%
# songs_info = {
#     'id':[],
#     'rating':[],
#     'views':[],
#     'likes':[],
#     'dislikes':[],
#     'comments':[]
# }




#     rating = r['items'][0]['contentDetails']['contentRating']
#     views = r['items'][0]['statistics']['viewCount']
#     likes = r['items'][0]['statistics']['likeCount']
# #     dislikes = r['items'][0]['statistics']['dislikeCount']
#     comments = r['items'][0]['statistics']['commentCount']
#     songs_info['id'].append(vidId)
#     songs_info['rating'].append(rating)
#     songs_info['views'].append(views)
#     songs_info['likes'].append(likes)
# #     songs_info['dislikes'].append(dislikes)
#     songs_info['comments'].append(comments)
